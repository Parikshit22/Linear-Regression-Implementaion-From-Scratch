# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dataset = pd.read_csv("dataset.csv")

# %%
x_train = dataset['x']
y_train = dataset['y']
x_train = (x_train-x_train.mean())/x_train.std()

# %%
plt.scatter(x_train,y_train)
plt.show()

# %%
def hypothesis(theta,x):
    return theta[0] + theta[1]*x

def error(X,Y,theta):
    total_error = 0
    m = X.shape[0]
    
    for i in range(m):
        total_error += (Y[i] - hypothesis(theta,X[i]))**2
    
    return 0.5*total_error

def gradient(Y,X,theta):
    grad = np.array([0.0,0.0])
    m = X.shape[0]
    for i in range(m):
        grad[0] += -1*(Y[i] - hypothesis(theta,X[i]))
        grad[1] += -1*(Y[i] - hypothesis(theta,X[i]))*X[i]        
    return grad

def gradientDescent(X,Y,learning_rate,maxItr):
    grad = np.array([0.0,0.0])
    theta = np.array([0.0,0.0])
    e = []
    
    for i in range(maxItr):
        grad = gradient(Y,X,theta)
        ce = error(X,Y,theta)
        print(ce)
        theta[0] = theta[0] - learning_rate*grad[0]
        theta[1] = theta[1] - learning_rate*grad[1]
        e.append(ce)
        
    return theta,e
                
theta,e = gradientDescent(x_train,y_train,learning_rate=0.001,maxItr=100)
print(theta[0],theta[1])
# Out:
# 49.16754909500004
# 39.91428771261432
# 32.40248083845625
# 26.30438848124974
# 21.353950987271144
# 17.335180862700767
# 14.07273924336281
# 11.42428586340651
# 9.274268752206911
# 7.528882704078776
# 6.1119765589324775
# 4.96173072860457
# 4.02796000939976
# 3.2699240026065106
# 2.654549611674936
# 2.1549880636425383
# 1.7494434976799207
# 1.4202220120969662
# 1.152959679748382
# 0.9359958501654003
# 0.7598643955975325
# 0.6168807040388417
# 0.500806399752286
# 0.40657716305500013
# 0.3300817741468973
# 0.2679827406690403
# 0.21757068297555635
# 0.1766461239512738
# 0.14342352586707494
# 0.11645338740278743
# 0.09455900193220006
# 0.07678511783538536
# 0.06235626088872886
# 0.05064290033933665
# 0.04113398249029108
# 0.03341463343760004
# 0.027148058129680505
# 0.022060846005684028
# 0.017931042097944667
# 0.01457846314097574
# 0.011856836179037348
# 0.009647416679870851
# 0.00785380771302368
# 0.006397754153615901
# 0.005215728412736619
# 0.0042561587299543395
# 0.0034771790983946266
# 0.0028448026516613286
# 0.0023314388175050883
# 0.0019146895416842639
# 0.001576372061286827
# 0.001301725591132371
# 0.001078767310997174
# 0.0008977695553974447
# 0.0007508353957304481
# 0.0006315540974307162
# 0.000534721419743946
# 0.00045611255480247707
# 0.0003922977993390527
# 0.00034049291679900923
# 0.00029843766115280273
# 0.00026429716240503254
# 0.00023658187125179183
# 0.0002140825700731168
# 0.00019581761479137342
# 0.0001809901057590633
# 0.0001689531190424679
# 0.00015918148114285886
# 0.00015124885568681596
# 0.00014480914237846032
# 0.00013958137665019804
# 0.00013533747118403514
# 0.00013189226446625908
# 0.00012909544219419602
# 0.00012682497906603562
# 0.00012498181481927867
# 0.00012348553223339912
# 0.0001222708485280405
# 0.00012128476707658292
# 0.00012048426516432985
# 0.00011983441690830334
# 0.00011930686944164681
# 0.000118878605878579
# 0.00011853094108811928
# 0.00011824870646217562
# 0.00011801958810947465
# 0.00011783358960071975
# 0.00011768259582457006
# 0.00011756001892549043
# 0.00011746051087574837
# 0.00011737973014105848
# 0.0001173141522595306
# 0.00011726091606946235
# 0.00011721769887691336
# 0.00011718261511660864
# 0.0001171541340847664
# 0.00011713101315452047
# 0.00011711224356013042
# 0.00011709700638455939
# 0.00011708463683012946
# 0.9966045602774349 0.0013648051857156971

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,hypothesis(theta,x_train))
plt.show()

# %% [markdown]
# # 3D Surface Plot

# %%
#from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(-4,4,0.02)
y = x

a,b = np.meshgrid(x,y)
print(a)
print(b)
# Out:
# [[-4.   -3.98 -3.96 ...  3.94  3.96  3.98]
#  [-4.   -3.98 -3.96 ...  3.94  3.96  3.98]
#  [-4.   -3.98 -3.96 ...  3.94  3.96  3.98]
#  ...
#  [-4.   -3.98 -3.96 ...  3.94  3.96  3.98]
#  [-4.   -3.98 -3.96 ...  3.94  3.96  3.98]
#  [-4.   -3.98 -3.96 ...  3.94  3.96  3.98]]
# [[-4.   -4.   -4.   ... -4.   -4.   -4.  ]
#  [-3.98 -3.98 -3.98 ... -3.98 -3.98 -3.98]
#  [-3.96 -3.96 -3.96 ... -3.96 -3.96 -3.96]
#  ...
#  [ 3.94  3.94  3.94 ...  3.94  3.94  3.94]
#  [ 3.96  3.96  3.96 ...  3.96  3.96  3.96]
#  [ 3.98  3.98  3.98 ...  3.98  3.98  3.98]]

# %%
'''
m = a.shape[0]
n = a.shape[1]

for i in range(m):
    for j in range(n):
        print("(%d,%d)"%(b[i,j],a[i,j]),end = " ")
    print()
'''
# Out:
# '\nm = a.shape[0]\nn = a.shape[1]\n\nfor i in range(m):\n    for j in range(n):\n        print("(%d,%d)"%(b[i,j],a[i,j]),end = " ")\n    print()\n'

# %%
fig = plt.figure()
axes = fig.gca(projection = '3d')
axes.plot_surface(a,b,a**2+b**2,cmap = 'coolwarm')
plt.show()

# %%
fig = plt.figure()

axes = fig.gca(projection = '3d')
axes.contour(a,b,a**2+b**2,cmap = 'coolwarm')
plt.show()

# %%
plt.contour(a,b,a**2+b**2)
plt.show()
